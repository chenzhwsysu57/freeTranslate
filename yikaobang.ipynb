# %%
import json
import re 

# 定义文件路径
file_path = '/Users/chenzhiwei/Downloads/freeTranslate/麻醉试题/医考帮知识点题库(专硕).txt'
def read_third_line(file_path):
    with open(file_path, 'r') as file:
        # 读取所有行
        lines = file.readlines()
        # 检查是否有至少三行
        if len(lines) < 3:
            raise ValueError("文件中没有足够的行")
        # 获取第三行并按tab分割
        third_line = lines[2].strip()  # 第三行的索引是2
        return re.split(r'\s+', third_line)

# 示例用法

third_line_array = read_third_line(file_path)
for list in third_line_array:
    print(list)


seplist = [
    '[题型]: NUMBER_TYPE', 
    '考点:ZHUANSHUODAGANG',
    'TITLE',
    'OPTIONS',
    'ANSWER',
    'CHARPTER',
    'TITLE',
    'OPTIONS',
    'ANSWER',
    '[正确答案]  ：ANSWER',
    '[高频考点？]  ：ISGAOPINKAODIAN',
    '[科目]  ：SUBJECT',
    '[考点还原]       RESTORE',
    '[答案解析]       ：EXPLAIN',
    ]
# Out:
# [题型]:
# NUMBER_TYPE
# 考点:ZHUANSHUODAGANG
# TITLE
# OPTIONS
# ANSWER
# CHARPTER
# TITLE
# OPTIONS
# ANSWER
# [正确答案]
# ：ANSWER
# [高频考点？]
# ：ISGAOPINKAODIAN
# [科目]
# ：SUBJECT
# [考点还原]
# RESTORE
# [答案解析]
# ：EXPLAIN

# %%
data[:10]
# Out:
# [{'题型': 'NUMBER_TYPE 考点:ZHUANSHUODAGANG  TITLE  OPTIONS ANSWER',
#   '考点': 'CHARPTER TITLE  OPTIONS ANSWER [正确答案]  ：ANSWER [高频考点？]  ：ISGAOPINKAODIAN [科目]  ：SUBJECT         [考点还原]       RESTORE        [答案解析]       ：EXPLAIN',
#   'TITLE_OPTIONS_ANSWER': '',
#   'CHARPTER_TITLE_OPTIONS_ANSWER': '',
#   '正确答案': '',
#   '高频考点': '',
#   '科目': '',
#   '考点还原': '',
#   '答案解析': ''},
#  {'题型': 'A 考点:细胞适应的分类  1[2009N41A]  下列选项中，不符合萎缩特点的是  A.自噬小体增多|B.器官均匀性缩小|C.器官功能低下|D.细胞核固缩 D',
# ...
