# %%
import time
import pyperclip as clip
import tagui as t 
t.init(visual_automation = True)
t.url('https://www.chatgpt.com')
import sys 
if sys.platform == 'darwin':
    MODIFIER = '[cmd]'
elif sys.platform == 'linux':
    MODIFIER = '[ctrl]'
else:
    raise NotImplementedError(f"{sys.platform} not implmented!")
def wait_until_present(selector, timeout=10):
    start_time = time.time()
    while time.time() - start_time < timeout:
        if t.present(selector):
            return True
        time.sleep(1)  # 等待1秒后再次检查
    raise TimeoutError(f"超过等待时间 {timeout} 秒，无法找到元素 {selector}")

def wait_until_present_count(selector, timeout=5, count = 1):
    start_time = time.time()
    while time.time() - start_time < timeout:
        if t.count(selector) == count:
            return True
        time.sleep(1)  # 等待1秒后再次检查
    raise TimeoutError(f"超过等待时间 {timeout} 秒，无法找到元素 {selector}")

text = """
以下内容可以被用于医学模型Q&A的训练。但是没有被格式化。而且有噪声。请你帮我提取格式化成正确的json形式：
[{"query": 问题, "answer": 答案},
{"query": 问题, "answer": 答案},
...
]

注意，不要返回其他内容。需要保证生成结果的json格式完整。

内容如下：晶体液和胶体液进行液体治疗有什么区别？	1.晶体液： ①既能补充血容量，又能补充离子 ②有利于休克后肾衰竭的防治 ③易产生组织水肿 2.胶体液： 对扩容效果好，输入后大部分留在血管内
手术前应该做哪些准备？	患者生命安全的需要； 全面了解健康状况及病情； 评估患者对手术及麻醉的耐受性； 寻找危险因素； 制定麻醉方案
ASA分级？	
局麻药毒性反应的防治	1.预防 ①重视麻醉前准备，对病人进行充分的术前评估 ②控制局麻药剂量和注意操作技术 2.治疗 ①一般处理：出现局麻药中毒的症状和体征后，应立即停止注入局麻药，同时进行有效的气道管理，给予纯氧 ②发生抽搐或惊厥时要注意保护病人，避免发生意外的损伤 ③药物治疗：发生抽搐或惊厥时，静脉用药首选苯二氮卓类药物，也可使用丙泊酚或硫喷妥钠；心率降低可使用阿托品、黄麻碱、肾上腺素
如何进行气道管理/维持气道通畅的方法？	托下颌通气道的使用面罩通气气管内插管气管切开喉罩通气道食管-气管联合导管
局麻药的不良反应	1.中枢神经系统毒性反应 眩晕、口周麻木、耳鸣、视物不清——意识丧失，昏迷——强直阵挛性惊厥 2.心血管系统毒性反应 心动过速和高血压——血压下降，心率缓慢 3.过敏反应 皮肤红斑、荨麻疹、咽喉水肿、支气管痉挛、休克
蛛网膜下腔阻滞的适应证	下腹及盆腔手术：如阑尾切除术 肛门及会阴手术：如肛瘘切除术 下肢手术：如截肢术 分娩镇痛
蛛网膜下腔阻滞的并发症	1.腰麻后头痛（最常见） 2.尿潴留 3.神经并发症 ①脑神经受累 ②假性脑脊膜炎 ③粘连性蛛网膜炎 ④马尾神经综合征  （腰麻后头痛的原因是脑脊液经穿刺孔漏出引起颅内压降低和颅内血管扩张。）
硬膜外阻滞的适应证	主要适应于腹部手术，颈部、上肢及胸部手术也可应用
硬膜外阻滞的并发症	1.穿破硬脊膜 2.穿刺针或导管误入血管 3.导管折断 4.全脊麻 5.脊神经根或脊髓损伤 6.硬膜外血肿
全身麻醉的分类	吸入全身麻醉 静脉全身麻醉 静吸复合全身麻醉
[...]是麻醉维持的三大要素	镇静、镇痛和肌松是麻醉维持的三大要素
全身麻醉的特点（临床表现）	意识消失、全身的痛觉丧失、遗忘、反射抑制和一定程度的肌肉松弛
全身麻醉的并发症	1.反流与误吸 2.呼吸道梗阻 3.通气量不足 4.低氧血症 5.术中知晓 6.恶性高热 7.苏醒延迟 8.低体温
常见的气道管理技术	口咽通气管 鼻咽通气管 面罩通气 气管插管技术
控制性降压对机体的影响	主要是脑缺血和心肌缺血 肾小球滤过率下降 肝损伤 眼内压下降，视力障碍
当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在[...]ml/（100·min)	当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)
当脑平均动脉压（MAP）在[...]mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)	当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)
当收缩压降至[...]mmHg时，肾小球滤过率将随血压下降而降低	当收缩压降至70mmHg时，肾小球滤过率将随血压下降而降低
当收缩压低于[...]mmHg时可能诱发肝损伤	当收缩压低于60mmHg时可能诱发肝损伤
控制性降压的适应证	（BP：血压； ICP：颅内压）
控制性降压的禁忌症	重要器官实质性病变血管病变严重贫血或低血容量颅内压增高病人，在手术开颅前禁止降压有明显机体、器官、组织氧运输降低，酌情未治疗的青光眼
围手术期导致机体低温的因素（低于36℃）	
围手术期导致机体体温过高的因素	
PACU离室的标准	SpO2:血氧饱和度 循环系统：稳定，心率和血压不超过术前值的+-20%并稳定30分钟以上 Steward苏醒评分 Aldrete 评分标准
ICU的转入标准	各种复杂大手术后的危重病人需行呼吸管理和（或）呼吸支持病人多器官功能障碍综合征病人心肺脑复苏后的病人心功能不全，或有严重心律失常病人严重创伤病人器官移植病人短期强化治疗可恢复的急性病人
ICU的转出标准	
氧交换功能的测量指标	动脉血氧分压(PaO2) 动脉血氧含量(CaO2)脉搏血氧饱和度(SpO2）混合静脉血氧饱和度(SvO2)肺泡气-动脉血氧分压差呼吸气中氧浓度氧摄取率(O2ER)氧合指数(PaO2/FiO2)P50
低氧血症的唯一指标是	动脉血氧分压
什么是氧供？	机体通过循环系统单位时间内向组织提供的氧量，即动脉血单位时间内运送氧的速率
氧供的正常值	520-720ml/(min·m2)
氧耗的正常值	110-180ml/(min·m2)
什么是氧耗	单位时间全身组织消耗氧的总量
氧耗增加的因素	SIRS:全身炎症反应综合征
急性呼吸窘迫综合征的临床表现	1.症状和体征 2.影像学检查 3.实验室检查 4.分期
ARDS的临床表现之症状和体征	1.症状 呼吸频数和呼吸窘迫，缺氧、烦躁、出汗，吸氧无缓解 2.体征 早期：呼吸频率加快，双肺闻及少量细湿罗音 进展：闻及水泡音，管状呼吸音
ARDS的临床表现之影像学表现	1.X线胸片 早期：阴性，轻度间质改变 进展：肺纹理增加、斑片状阴影 后期：实变影，“白肺”，支气管充气征 2.CT 更准确的反应病变肺区域的大小
ARDS的临床表现之实验室检查	1.动脉血气分析： PaO2↓，PaCO2↓，PH先↑后↓ PaO2/FiO2↓（必要条件） 2.肺力学检测： 顺应性↓ 气道阻力↑ 3.肺功能检测： 肺容量、肺活量、FRC均↓ 无效腔↑ 动静脉分流↑ 4.血流动力学监测 PAWP（肺动脉楔压）正常或降低； 若PAWP＞18mmHg，则左心衰竭 5.支气管肺泡灌洗液(BALF) 中性粒细胞↑ 蛋白浓度↑ 肺毛细血管渗漏综合征 6.PiCCO（经胸热稀释法）： 肺毛细血管屏障受损、肺水高于心源性肺水肿
ARDS的临床表现之ARDS的分期	1、第一期 (急性损伤期)：  2、第二期 (相对稳定期)：  3、第三期 (急性呼吸衰竭期)：  4、第四期 (终末期)：
ARDS的诊断标准	(1)发病时间 (2)胸部X线或CT成像 (3)水肿原因                (4)氧合
ARDS的治疗原则	(一)控制原发病与感染的治疗  (二)呼吸支持治疗       (三)液体管理：在保证组织灌注的前提下，限制性的液体管理，维持CO (四)药物治疗  (五)营养代谢支持：尽早给予有力的营养支持 (六)维护重要器官功能，防止MODS
氧治疗的适应证	1、纠正低氧血症：针对病因，提高FiO2 2、阻断因缺氧引起的不良反应： 缺氧代偿： 呼吸做功↑氧耗↑呼吸衰竭   心脏做功↑氧耗↑循环衰竭 3、氧治疗的临床适应证： 呼衰、心衰或心梗、休克  烧伤或感染引起的代谢增加  心搏骤停复苏、CO中毒或术后
氧治疗的并发症	1、急性通气功能障碍：COPD       2、吸收性肺不张：FiO2＜50%，较安全  3、氧中毒：长时间吸入高浓度氧    肺水肿、肺泡充血、肺间质改变  顽固性低氧血症、肺萎陷、顺应性降低   1⃣️多发生在慢性阻塞性肺疾病(COPD)病人，平常即有CO2潴留和高碳酸血症，延髓呼吸中枢已适应了升高的CO2,其呼吸功能主要依靠低PaO2刺激颈动脉体的化学感受器引起反射性兴奋来维持。 2⃣️吸入高浓度氧后可将氮气置换出来，结果使肺泡失去了氮气的支撑。随着氧的吸收，肺泡的直径逐渐变小，结果可发生肺萎陷或肺不张

"""

try:
    clip.copy(text)
    wait_until_present("//textarea[@id='prompt-textarea']")
    t.keyboard('[esc]')
    res = t.click("//textarea[@id='prompt-textarea']")
    # res = t.type("//textarea[@id='prompt-textarea']", "你好")
    print(f"点击状态: {res}")
    res = t.keyboard(f"{MODIFIER}v")
    print(f"粘贴状态: {res}")
    wait_until_present("//button[@data-testid='send-button']")
    res = t.click("//button[@data-testid='send-button']")
    print(f"点击发送状态：{res}")

    wait_until_present_count("//button[contains(@class, 'rounded-lg')]", timeout=60,count=12)
    # 等待过程中如果出现了向下的箭头
    if t.present("//button[contains(@class, 'cursor-pointer absolute z-10')]"):
        t.click("//button[contains(@class, 'cursor-pointer absolute z-10')]")
        wait_until_present_count("//button[contains(@class, 'rounded-lg')]", timeout=60,count=12)
    if t.present("继续生成"):
        t.click("继续生成")
        wait_until_present_count("//button[contains(@class, 'rounded-lg')]", timeout=60,count=12)
    wait_until_present_count("//button[contains(@class, 'rounded-lg')]", timeout=60,count=12)
    # res = t.click("(//button[contains(@class, 'rounded-lg')])[9]")
    # print(f"复制状态: {res}")
    if t.present("复制代码"):
        res = t.click("复制代码")
    # t.close()
except TimeoutError as e:
    print(f"出现超时错误：{e}")

# %%
# 更改代码更好看点
import time
import pyperclip as clip
import tagui as t 

t.init(visual_automation = True)
t.url('https://www.chatgpt.com')
import sys 
if sys.platform == 'darwin':
    MODIFIER = '[cmd]'
elif sys.platform == 'linux':
    MODIFIER = '[ctrl]'
else:
    raise NotImplementedError(f"{sys.platform} not implmented!")
def wait_until_present(selector, timeout=10):
    start_time = time.time()
    while time.time() - start_time < timeout:
        if t.present(selector):
            return True
        time.sleep(1)  # 等待1秒后再次检查
    raise TimeoutError(f"超过等待时间 {timeout} 秒，无法找到元素 {selector}")

def wait_until_present_count(selector, timeout=5, count = 1):
    start_time = time.time()
    while time.time() - start_time < timeout:
        if t.count(selector) == count:
            return True
        time.sleep(1)  # 等待1秒后再次检查
    raise TimeoutError(f"超过等待时间 {timeout} 秒，无法找到元素 {selector}")

text = """
以下内容可以被用于医学模型Q&A的训练。但是没有被格式化。而且有噪声。请你帮我提取格式化成正确的json形式：
[{"query": 问题, "answer": 答案},
{"query": 问题, "answer": 答案},
...
]

注意，不要返回其他内容。需要保证生成结果的json格式完整。

内容如下：晶体液和胶体液进行液体治疗有什么区别？	1.晶体液： ①既能补充血容量，又能补充离子 ②有利于休克后肾衰竭的防治 ③易产生组织水肿 2.胶体液： 对扩容效果好，输入后大部分留在血管内
手术前应该做哪些准备？	患者生命安全的需要； 全面了解健康状况及病情； 评估患者对手术及麻醉的耐受性； 寻找危险因素； 制定麻醉方案
ASA分级？	
局麻药毒性反应的防治	1.预防 ①重视麻醉前准备，对病人进行充分的术前评估 ②控制局麻药剂量和注意操作技术 2.治疗 ①一般处理：出现局麻药中毒的症状和体征后，应立即停止注入局麻药，同时进行有效的气道管理，给予纯氧 ②发生抽搐或惊厥时要注意保护病人，避免发生意外的损伤 ③药物治疗：发生抽搐或惊厥时，静脉用药首选苯二氮卓类药物，也可使用丙泊酚或硫喷妥钠；心率降低可使用阿托品、黄麻碱、肾上腺素
如何进行气道管理/维持气道通畅的方法？	托下颌通气道的使用面罩通气气管内插管气管切开喉罩通气道食管-气管联合导管
局麻药的不良反应	1.中枢神经系统毒性反应 眩晕、口周麻木、耳鸣、视物不清——意识丧失，昏迷——强直阵挛性惊厥 2.心血管系统毒性反应 心动过速和高血压——血压下降，心率缓慢 3.过敏反应 皮肤红斑、荨麻疹、咽喉水肿、支气管痉挛、休克
蛛网膜下腔阻滞的适应证	下腹及盆腔手术：如阑尾切除术 肛门及会阴手术：如肛瘘切除术 下肢手术：如截肢术 分娩镇痛
蛛网膜下腔阻滞的并发症	1.腰麻后头痛（最常见） 2.尿潴留 3.神经并发症 ①脑神经受累 ②假性脑脊膜炎 ③粘连性蛛网膜炎 ④马尾神经综合征  （腰麻后头痛的原因是脑脊液经穿刺孔漏出引起颅内压降低和颅内血管扩张。）
硬膜外阻滞的适应证	主要适应于腹部手术，颈部、上肢及胸部手术也可应用
硬膜外阻滞的并发症	1.穿破硬脊膜 2.穿刺针或导管误入血管 3.导管折断 4.全脊麻 5.脊神经根或脊髓损伤 6.硬膜外血肿
全身麻醉的分类	吸入全身麻醉 静脉全身麻醉 静吸复合全身麻醉
[...]是麻醉维持的三大要素	镇静、镇痛和肌松是麻醉维持的三大要素
全身麻醉的特点（临床表现）	意识消失、全身的痛觉丧失、遗忘、反射抑制和一定程度的肌肉松弛
全身麻醉的并发症	1.反流与误吸 2.呼吸道梗阻 3.通气量不足 4.低氧血症 5.术中知晓 6.恶性高热 7.苏醒延迟 8.低体温
常见的气道管理技术	口咽通气管 鼻咽通气管 面罩通气 气管插管技术
控制性降压对机体的影响	主要是脑缺血和心肌缺血 肾小球滤过率下降 肝损伤 眼内压下降，视力障碍
当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在[...]ml/（100·min)	当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)
当脑平均动脉压（MAP）在[...]mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)	当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)
当收缩压降至[...]mmHg时，肾小球滤过率将随血压下降而降低	当收缩压降至70mmHg时，肾小球滤过率将随血压下降而降低
当收缩压低于[...]mmHg时可能诱发肝损伤	当收缩压低于60mmHg时可能诱发肝损伤
控制性降压的适应证	（BP：血压； ICP：颅内压）
控制性降压的禁忌症	重要器官实质性病变血管病变严重贫血或低血容量颅内压增高病人，在手术开颅前禁止降压有明显机体、器官、组织氧运输降低，酌情未治疗的青光眼
围手术期导致机体低温的因素（低于36℃）	
围手术期导致机体体温过高的因素	
PACU离室的标准	SpO2:血氧饱和度 循环系统：稳定，心率和血压不超过术前值的+-20%并稳定30分钟以上 Steward苏醒评分 Aldrete 评分标准
ICU的转入标准	各种复杂大手术后的危重病人需行呼吸管理和（或）呼吸支持病人多器官功能障碍综合征病人心肺脑复苏后的病人心功能不全，或有严重心律失常病人严重创伤病人器官移植病人短期强化治疗可恢复的急性病人
ICU的转出标准	
氧交换功能的测量指标	动脉血氧分压(PaO2) 动脉血氧含量(CaO2)脉搏血氧饱和度(SpO2）混合静脉血氧饱和度(SvO2)肺泡气-动脉血氧分压差呼吸气中氧浓度氧摄取率(O2ER)氧合指数(PaO2/FiO2)P50
低氧血症的唯一指标是	动脉血氧分压
什么是氧供？	机体通过循环系统单位时间内向组织提供的氧量，即动脉血单位时间内运送氧的速率
氧供的正常值	520-720ml/(min·m2)
氧耗的正常值	110-180ml/(min·m2)
什么是氧耗	单位时间全身组织消耗氧的总量
氧耗增加的因素	SIRS:全身炎症反应综合征
急性呼吸窘迫综合征的临床表现	1.症状和体征 2.影像学检查 3.实验室检查 4.分期
ARDS的临床表现之症状和体征	1.症状 呼吸频数和呼吸窘迫，缺氧、烦躁、出汗，吸氧无缓解 2.体征 早期：呼吸频率加快，双肺闻及少量细湿罗音 进展：闻及水泡音，管状呼吸音
ARDS的临床表现之影像学表现	1.X线胸片 早期：阴性，轻度间质改变 进展：肺纹理增加、斑片状阴影 后期：实变影，“白肺”，支气管充气征 2.CT 更准确的反应病变肺区域的大小
ARDS的临床表现之实验室检查	1.动脉血气分析： PaO2↓，PaCO2↓，PH先↑后↓ PaO2/FiO2↓（必要条件） 2.肺力学检测： 顺应性↓ 气道阻力↑ 3.肺功能检测： 肺容量、肺活量、FRC均↓ 无效腔↑ 动静脉分流↑ 4.血流动力学监测 PAWP（肺动脉楔压）正常或降低； 若PAWP＞18mmHg，则左心衰竭 5.支气管肺泡灌洗液(BALF) 中性粒细胞↑ 蛋白浓度↑ 肺毛细血管渗漏综合征 6.PiCCO（经胸热稀释法）： 肺毛细血管屏障受损、肺水高于心源性肺水肿
ARDS的临床表现之ARDS的分期	1、第一期 (急性损伤期)：  2、第二期 (相对稳定期)：  3、第三期 (急性呼吸衰竭期)：  4、第四期 (终末期)：
ARDS的诊断标准	(1)发病时间 (2)胸部X线或CT成像 (3)水肿原因                (4)氧合
ARDS的治疗原则	(一)控制原发病与感染的治疗  (二)呼吸支持治疗       (三)液体管理：在保证组织灌注的前提下，限制性的液体管理，维持CO (四)药物治疗  (五)营养代谢支持：尽早给予有力的营养支持 (六)维护重要器官功能，防止MODS
氧治疗的适应证	1、纠正低氧血症：针对病因，提高FiO2 2、阻断因缺氧引起的不良反应： 缺氧代偿： 呼吸做功↑氧耗↑呼吸衰竭   心脏做功↑氧耗↑循环衰竭 3、氧治疗的临床适应证： 呼衰、心衰或心梗、休克  烧伤或感染引起的代谢增加  心搏骤停复苏、CO中毒或术后
氧治疗的并发症	1、急性通气功能障碍：COPD       2、吸收性肺不张：FiO2＜50%，较安全  3、氧中毒：长时间吸入高浓度氧    肺水肿、肺泡充血、肺间质改变  顽固性低氧血症、肺萎陷、顺应性降低   1⃣️多发生在慢性阻塞性肺疾病(COPD)病人，平常即有CO2潴留和高碳酸血症，延髓呼吸中枢已适应了升高的CO2,其呼吸功能主要依靠低PaO2刺激颈动脉体的化学感受器引起反射性兴奋来维持。 2⃣️吸入高浓度氧后可将氮气置换出来，结果使肺泡失去了氮气的支撑。随着氧的吸收，肺泡的直径逐渐变小，结果可发生肺萎陷或肺不张

"""

try:
    clip.copy(text)
    wait_until_present("//textarea[@id='prompt-textarea']")
    t.keyboard('[esc]')
    res = t.click("//textarea[@id='prompt-textarea']")
    # res = t.type("//textarea[@id='prompt-textarea']", "你好")
    print(f"点击状态: {res}")
    res = t.keyboard(f"{MODIFIER}v")
    print(f"粘贴状态: {res}")
    wait_until_present("//button[@data-testid='send-button']")
    res = t.click("//button[@data-testid='send-button']")
    print(f"点击发送状态：{res}")

    # wait until no stop button
    # //button[contains(@data-testid, 'stop-button')]
    def wait_til_no_stop_button():
        i = 1
        while not t.present("//button[contains(@data-testid, 'stop-button')]"):
            i = 0 
        return
  
    wait_until_present_count("//button[contains(@class, 'rounded-lg')]", timeout=60,count=12)
    # 等待过程中如果出现了向下的箭头
    if t.present("//button[contains(@class, 'cursor-pointer absolute z-10')]"):
        t.click("//button[contains(@class, 'cursor-pointer absolute z-10')]")
        wait_until_present_count("//button[contains(@class, 'rounded-lg')]", timeout=60,count=12)
    if t.present("继续生成"):
        t.click("继续生成")
        wait_til_no_stop_button()
        wait_until_present_count("//button[contains(@class, 'rounded-lg')]", timeout=60,count=12)
    wait_until_present_count("//button[contains(@class, 'rounded-lg')]", timeout=60,count=12)
    # res = t.click("(//button[contains(@class, 'rounded-lg')])[9]")
    # print(f"复制状态: {res}")
    if t.present("复制代码"):
        res = t.click("复制代码")
    # t.close()
except TimeoutError as e:
    print(f"出现超时错误：{e}")

# %%
[
    {
        "query": "晶体液和胶体液进行液体治疗有什么区别？",
        "answer": "1.晶体液： ①既能补充血容量，又能补充离子 ②有利于休克后肾衰竭的防治 ③易产生组织水肿 2.胶体液： 对扩容效果好，输入后大部分留在血管内"
    },
    {
        "query": "手术前应该做哪些准备？",
        "answer": "患者生命安全的需要； 全面了解健康状况及病情； 评估患者对手术及麻醉的耐受性； 寻找危险因素； 制定麻醉方案"
    },
    {
        "query": "ASA分级？",
        "answer": ""
    },
    {
        "query": "局麻药毒性反应的防治",
        "answer": "1.预防 ①重视麻醉前准备，对病人进行充分的术前评估 ②控制局麻药剂量和注意操作技术 2.治疗 ①一般处理：出现局麻药中毒的症状和体征后，应立即停止注入局麻药，同时进行有效的气道管理，给予纯氧 ②发生抽搐或惊厥时要注意保护病人，避免发生意外的损伤 ③药物治疗：发生抽搐或惊厥时，静脉用药首选苯二氮卓类药物，也可使用丙泊酚或硫喷妥钠；心率降低可使用阿托品、黄麻碱、肾上腺素"
    },
    {
        "query": "如何进行气道管理/维持气道通畅的方法？",
        "answer": "托下颌通气道的使用面罩通气气管内插管气管切开喉罩通气道食管-气管联合导管"
    },
    {
        "query": "局麻药的不良反应",
        "answer": "1.中枢神经系统毒性反应 眩晕、口周麻木、耳鸣、视物不清——意识丧失，昏迷——强直阵挛性惊厥 2.心血管系统毒性反应 心动过速和高血压——血压下降，心率缓慢 3.过敏反应 皮肤红斑、荨麻疹、咽喉水肿、支气管痉挛、休克"
    },
    {
        "query": "蛛网膜下腔阻滞的适应证",
        "answer": "下腹及盆腔手术：如阑尾切除术 肛门及会阴手术：如肛瘘切除术 下肢手术：如截肢术 分娩镇痛"
    },
    {
        "query": "蛛网膜下腔阻滞的并发症",
        "answer": "1.腰麻后头痛（最常见） 2.尿潴留 3.神经并发症 ①脑神经受累 ②假性脑脊膜炎 ③粘连性蛛网膜炎 ④马尾神经综合征  （腰麻后头痛的原因是脑脊液经穿刺孔漏出引起颅内压降低和颅内血管扩张。）"
    },
    {
        "query": "硬膜外阻滞的适应证",
        "answer": "主要适应于腹部手术，颈部、上肢及胸部手术也可应用"
    },
    {
        "query": "硬膜外阻滞的并发症",
        "answer": "1.穿破硬脊膜 2.穿刺针或导管误入血管 3.导管折断 4.全脊麻 5.脊神经根或脊髓损伤 6.硬膜外血肿"
    },
    {
        "query": "全身麻醉的分类",
        "answer": "吸入全身麻醉 静脉全身麻醉 静吸复合全身麻醉"
    },
    {
        "query": "[...]是麻醉维持的三大要素",
        "answer": "镇静、镇痛和肌松是麻醉维持的三大要素"
    },
    {
        "query": "全身麻醉的特点（临床表现）",
        "answer": "意识消失、全身的痛觉丧失、遗忘、反射抑制和一定程度的肌肉松弛"
    },
    {
        "query": "全身麻醉的并发症",
        "answer": "1.反流与误吸 2.呼吸道梗阻 3.通气量不足 4.低氧血症 5.术中知晓 6.恶性高热 7.苏醒延迟 8.低体温"
    },
    {
        "query": "常见的气道管理技术",
        "answer": "口咽通气管 鼻咽通气管 面罩通气 气管插管技术"
    },
    {
        "query": "控制性降压对机体的影响",
        "answer": "主要是脑缺血和心肌缺血 肾小球滤过率下降 肝损伤 眼内压下降，视力障碍"
    },
    {
        "query": "当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在[...]ml/（100·min)",
        "answer": "当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)"
    },
    {
        "query": "当脑平均动脉压（MAP）在[...]mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)",
        "answer": "当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)"
    },
    {
        "query": "当收缩压降至[...]mmHg时，肾小球滤过率将随血压下降而降低",
        "answer": "当收缩压降至70mmHg时，肾小球滤过率将随血压下降而降低"
    },
    {
        "query": "当收缩压低于[...]mmHg时可能诱发肝损伤",
        "answer": "当收缩压低于60mmHg时可能诱发肝损伤"
    },
    {
        "query": "控制性降压的适应证",
        "answer": "（BP：血压； ICP：颅内压）"
    },
    {
        "query": "控制性降压的禁忌症",
        "answer": "重要器官实质性病变血管病变严重贫血或低血容量颅内压增高病人，在手术开颅前禁止降压有明显机体、器官、组织氧运输降低，酌情未治疗的青光眼"
    },
    {
        "query": "围手术期导致机体低温的因素（低于36℃）",
        "answer": ""
    },
    {
        "query": "围手术期导致机体体温过高的因素",
        "answer": ""
    },
    {
        "query": "PACU离室的标准",
        "answer": "SpO2:血氧饱和度 循环系统：稳定，心率和血压不超过术前值的+-20%并稳定30分钟以上 Steward苏醒评分 Aldrete 评分标准"
    },
    {
        "query": "ICU的转入标准",
        "answer": "各种复杂大手术后的危重病人需行呼吸管理和（或）呼吸支持病人多器官功能障碍综合征病人心肺脑复苏后的病人心功能不全，或有严重心律失常病人严重创伤病人器官移植病人短期强化治疗可恢复的急性病人"
    },
    {
        "query": "ICU的转出标准",
        "answer": ""
    },
    {
        "query": "氧交换功能的测量指标",
        "answer": "动脉血氧分压(PaO2) 动脉血氧含量(CaO2)脉搏血氧饱和度(SpO2）混合静脉血氧饱和度(SvO2)肺泡气-动脉血氧分压差呼吸气中氧浓度氧摄取率(O2ER)氧合指数(PaO2/FiO2)P50"
    },
    {
        "query": "低氧血症的唯一指标是",
        "answer": "动脉血氧分压"
    },
    {
        "query": "什么是氧供？",
        "answer": "机体通过循环系统单位时间内向组织提供的氧量，即动脉血单位时间内运送氧的速率"
    },
    {
        "query": "氧供的正常值",
        "answer": "520-720ml/(min·m2)"
    },
    {
        "query": "氧耗的正常值",
        "answer": "110-180ml/(min·m2)"
    },
    {
        "query": "什么是氧耗",
        "answer": "单位时间全身组织消耗氧的总量"
    },
    {
        "query": "氧耗增加的因素",
        "answer": "SIRS:全身炎症反应综合征"
    },
    {
        "query": "急性呼吸窘迫综合征的临床表现",
        "answer": "1.症状和体征 2.影像学检查 3.实验室检查 4.分期"
    },
    {
        "query": "ARDS的临床表现之症状和体征",
        "answer": "1.症状 呼吸频数和呼吸窘迫，缺氧、烦躁、出汗，吸氧无缓解 2.体征 早期：呼吸频率加快，双肺闻及少量细湿罗音 进展：闻及水泡音，管状呼吸音"
    },
    {
        "query": "ARDS的临床表现之影像学表现",
        "answer": "1.X线胸片 早期：阴性，轻度间质改变 进展：肺纹理增加、斑片状阴影 后期：实变影，“白肺”，支气管充气征 2.CT 更准确的反应病变肺区域的大小"
    },
    {
        "query": "ARDS的临床表现之实验室检查",
        "answer": "1.动脉血气分析： PaO2↓，PaCO2↓，PH先↑后↓ PaO2/FiO2↓（必要条件） 2.肺力学检测： 顺应性↓ 气道阻力↑ 3.肺功能检测： 肺容量、肺活量、FRC均↓ 无效腔↑ 动静脉分流↑ 4.血流动力学监测 PAWP（肺动脉楔压）正常或降低； 若PAWP＞18mmHg，则左心衰竭 5.支气管肺泡灌洗液(BALF) 中性粒细胞↑ 蛋白浓度↑ 肺毛细血管渗漏综合征 6.PiCCO（经胸热稀释法）： 肺毛细血管屏障受损、肺水高于心源性肺水肿"
    },
    {
        "query": "ARDS的临床表现之ARDS的分期",
        "answer": "1、第一期 (急性损伤期)：  2、第二期 (相对稳定期)：  3、第三期 (急性呼吸衰竭期)：  4、第四期 (终末期)："
    },
    {
        "query": "ARDS的诊断标准",
        "answer": "(1)发病时间 (2)胸部X线或CT成像 (3)水肿原因                (4)氧合"
    },
    {
        "query": "ARDS的治疗原则",
        "answer": "(一)控制原发病与感染的治疗  (二)呼吸支持治疗       (三)液体管理：在保证组织灌注的前提下，限制性的液体管理，维持CO (四)药物治疗  (五)营养代谢支持：尽早给予有力的营养支持 (六)维护重要器官功能，防止MODS"
    },
    {
        "query": "氧治疗的适应证",
        "answer": "1、纠正低氧血症：针对病因，提高FiO2 2、阻断因缺氧引起的不良反应： 缺氧代偿： 呼吸做功↑氧耗↑呼吸衰竭   心脏做功↑氧耗↑循环衰竭 3、氧治疗的临床适应证： 呼衰、心衰或心梗、休克  烧伤或感染引起的代谢增加  心搏骤停复苏、CO中毒或术后"
    },
    {
        "query": "氧治疗的并发症",
        "answer": "1、急性通气功能障碍：COPD       2、吸收性肺不张：FiO2＜50%，较安全  3、氧中毒：长时间吸入高浓度氧    肺水肿、肺泡充血、肺间质改变  顽固性低氧血症、肺萎陷、顺应性降低   1⃣️多发生在慢性阻塞性肺疾病(COPD)病人，平常即有CO2潴留和高碳酸血症，延髓呼吸中枢已适应了升高的CO2,其呼吸功能主要依靠低PaO2刺激颈动脉体的化学感受器引起反射性兴奋来维持。 2⃣️吸入高浓度氧后可将氮气置换出来，结果使肺泡失去了氮气的支撑。随着氧的吸收，肺泡的直径逐渐变小，结果可发生肺萎陷或肺不张"
    }
]
# Out:
# True

# %%
text = """
以下内容可以被用于医学模型Q&A的训练。但是没有被格式化。而且有噪声。请你帮我提取格式化成正确的json形式：
[{"query": 问题, "answer": 答案},
{"query": 问题, "answer": 答案},
...
]

注意，不要返回其他内容。需要保证生成结果的json格式完整。

内容如下：晶体液和胶体液进行液体治疗有什么区别？	1.晶体液： ①既能补充血容量，又能补充离子 ②有利于休克后肾衰竭的防治 ③易产生组织水肿 2.胶体液： 对扩容效果好，输入后大部分留在血管内
手术前应该做哪些准备？	患者生命安全的需要； 全面了解健康状况及病情； 评估患者对手术及麻醉的耐受性； 寻找危险因素； 制定麻醉方案
ASA分级？	
局麻药毒性反应的防治	1.预防 ①重视麻醉前准备，对病人进行充分的术前评估 ②控制局麻药剂量和注意操作技术 2.治疗 ①一般处理：出现局麻药中毒的症状和体征后，应立即停止注入局麻药，同时进行有效的气道管理，给予纯氧 ②发生抽搐或惊厥时要注意保护病人，避免发生意外的损伤 ③药物治疗：发生抽搐或惊厥时，静脉用药首选苯二氮卓类药物，也可使用丙泊酚或硫喷妥钠；心率降低可使用阿托品、黄麻碱、肾上腺素
如何进行气道管理/维持气道通畅的方法？	托下颌通气道的使用面罩通气气管内插管气管切开喉罩通气道食管-气管联合导管
局麻药的不良反应	1.中枢神经系统毒性反应 眩晕、口周麻木、耳鸣、视物不清——意识丧失，昏迷——强直阵挛性惊厥 2.心血管系统毒性反应 心动过速和高血压——血压下降，心率缓慢 3.过敏反应 皮肤红斑、荨麻疹、咽喉水肿、支气管痉挛、休克
蛛网膜下腔阻滞的适应证	下腹及盆腔手术：如阑尾切除术 肛门及会阴手术：如肛瘘切除术 下肢手术：如截肢术 分娩镇痛
蛛网膜下腔阻滞的并发症	1.腰麻后头痛（最常见） 2.尿潴留 3.神经并发症 ①脑神经受累 ②假性脑脊膜炎 ③粘连性蛛网膜炎 ④马尾神经综合征  （腰麻后头痛的原因是脑脊液经穿刺孔漏出引起颅内压降低和颅内血管扩张。）
硬膜外阻滞的适应证	主要适应于腹部手术，颈部、上肢及胸部手术也可应用
硬膜外阻滞的并发症	1.穿破硬脊膜 2.穿刺针或导管误入血管 3.导管折断 4.全脊麻 5.脊神经根或脊髓损伤 6.硬膜外血肿
全身麻醉的分类	吸入全身麻醉 静脉全身麻醉 静吸复合全身麻醉
[...]是麻醉维持的三大要素	镇静、镇痛和肌松是麻醉维持的三大要素
全身麻醉的特点（临床表现）	意识消失、全身的痛觉丧失、遗忘、反射抑制和一定程度的肌肉松弛
全身麻醉的并发症	1.反流与误吸 2.呼吸道梗阻 3.通气量不足 4.低氧血症 5.术中知晓 6.恶性高热 7.苏醒延迟 8.低体温
常见的气道管理技术	口咽通气管 鼻咽通气管 面罩通气 气管插管技术
控制性降压对机体的影响	主要是脑缺血和心肌缺血 肾小球滤过率下降 肝损伤 眼内压下降，视力障碍
当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在[...]ml/（100·min)	当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)
当脑平均动脉压（MAP）在[...]mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)	当脑平均动脉压（MAP）在50-150mmHg内，可维持脑血流（CBF）恒定在50ml/（100·min)
当收缩压降至[...]mmHg时，肾小球滤过率将随血压下降而降低	当收缩压降至70mmHg时，肾小球滤过率将随血压下降而降低
当收缩压低于[...]mmHg时可能诱发肝损伤	当收缩压低于60mmHg时可能诱发肝损伤
控制性降压的适应证	（BP：血压； ICP：颅内压）
控制性降压的禁忌症	重要器官实质性病变血管病变严重贫血或低血容量颅内压增高病人，在手术开颅前禁止降压有明显机体、器官、组织氧运输降低，酌情未治疗的青光眼
围手术期导致机体低温的因素（低于36℃）	
围手术期导致机体体温过高的因素	
PACU离室的标准	SpO2:血氧饱和度 循环系统：稳定，心率和血压不超过术前值的+-20%并稳定30分钟以上 Steward苏醒评分 Aldrete 评分标准
ICU的转入标准	各种复杂大手术后的危重病人需行呼吸管理和（或）呼吸支持病人多器官功能障碍综合征病人心肺脑复苏后的病人心功能不全，或有严重心律失常病人严重创伤病人器官移植病人短期强化治疗可恢复的急性病人
ICU的转出标准	
氧交换功能的测量指标	动脉血氧分压(PaO2) 动脉血氧含量(CaO2)脉搏血氧饱和度(SpO2）混合静脉血氧饱和度(SvO2)肺泡气-动脉血氧分压差呼吸气中氧浓度氧摄取率(O2ER)氧合指数(PaO2/FiO2)P50
低氧血症的唯一指标是	动脉血氧分压
什么是氧供？	机体通过循环系统单位时间内向组织提供的氧量，即动脉血单位时间内运送氧的速率
氧供的正常值	520-720ml/(min·m2)
氧耗的正常值	110-180ml/(min·m2)
什么是氧耗	单位时间全身组织消耗氧的总量
氧耗增加的因素	SIRS:全身炎症反应综合征
急性呼吸窘迫综合征的临床表现	1.症状和体征 2.影像学检查 3.实验室检查 4.分期
ARDS的临床表现之症状和体征	1.症状 呼吸频数和呼吸窘迫，缺氧、烦躁、出汗，吸氧无缓解 2.体征 早期：呼吸频率加快，双肺闻及少量细湿罗音 进展：闻及水泡音，管状呼吸音
ARDS的临床表现之影像学表现	1.X线胸片 早期：阴性，轻度间质改变 进展：肺纹理增加、斑片状阴影 后期：实变影，“白肺”，支气管充气征 2.CT 更准确的反应病变肺区域的大小
ARDS的临床表现之实验室检查	1.动脉血气分析： PaO2↓，PaCO2↓，PH先↑后↓ PaO2/FiO2↓（必要条件） 2.肺力学检测： 顺应性↓ 气道阻力↑ 3.肺功能检测： 肺容量、肺活量、FRC均↓ 无效腔↑ 动静脉分流↑ 4.血流动力学监测 PAWP（肺动脉楔压）正常或降低； 若PAWP＞18mmHg，则左心衰竭 5.支气管肺泡灌洗液(BALF) 中性粒细胞↑ 蛋白浓度↑ 肺毛细血管渗漏综合征 6.PiCCO（经胸热稀释法）： 肺毛细血管屏障受损、肺水高于心源性肺水肿
ARDS的临床表现之ARDS的分期	1、第一期 (急性损伤期)：  2、第二期 (相对稳定期)：  3、第三期 (急性呼吸衰竭期)：  4、第四期 (终末期)：
ARDS的诊断标准	(1)发病时间 (2)胸部X线或CT成像 (3)水肿原因                (4)氧合
ARDS的治疗原则	(一)控制原发病与感染的治疗  (二)呼吸支持治疗       (三)液体管理：在保证组织灌注的前提下，限制性的液体管理，维持CO (四)药物治疗  (五)营养代谢支持：尽早给予有力的营养支持 (六)维护重要器官功能，防止MODS
氧治疗的适应证	1、纠正低氧血症：针对病因，提高FiO2 2、阻断因缺氧引起的不良反应： 缺氧代偿： 呼吸做功↑氧耗↑呼吸衰竭   心脏做功↑氧耗↑循环衰竭 3、氧治疗的临床适应证： 呼衰、心衰或心梗、休克  烧伤或感染引起的代谢增加  心搏骤停复苏、CO中毒或术后
氧治疗的并发症	1、急性通气功能障碍：COPD       2、吸收性肺不张：FiO2＜50%，较安全  3、氧中毒：长时间吸入高浓度氧    肺水肿、肺泡充血、肺间质改变  顽固性低氧血症、肺萎陷、顺应性降低   1⃣️多发生在慢性阻塞性肺疾病(COPD)病人，平常即有CO2潴留和高碳酸血症，延髓呼吸中枢已适应了升高的CO2,其呼吸功能主要依靠低PaO2刺激颈动脉体的化学感受器引起反射性兴奋来维持。 2⃣️吸入高浓度氧后可将氮气置换出来，结果使肺泡失去了氮气的支撑。随着氧的吸收，肺泡的直径逐渐变小，结果可发生肺萎陷或肺不张

"""
# Out:
# True

# %% [markdown]
# # 代码测试开始

# %%
import json
import tagui as t
import time 
import os 
import pyperclip as clip

import sys 
if sys.platform == 'darwin':
    MODIFIER = '[cmd]'
elif sys.platform == 'linux':
    MODIFIER = '[ctrl]'
else:
    raise NotImplementedError(f"{sys.platform} not implmented!")


def write_json(filename, content):
    # 不保证json格式完整
    with open(filename, 'w') as file:
        file.write(content)

def split_txt(filepath):
    sections = []
    overlap = 200
    section_length = 3000

    try:
        with open(filepath, 'r', encoding='utf-8') as file:
            content = file.read()

        start = 0
        while start < len(content):
            end = start + section_length
            section = content[start:end]
            sections.append(section)
            start += section_length - overlap

        return sections
    except Exception as e:
        print(f"Cannot open {filepath}: {e}")
        return sections

prefix_prompt = """
以下内容来自Anki用户牌组导出的部分txt。 Anki牌组导出的内容可以被用于医学模型Q&A的训练。但是没有被格式化。txt文件的内容不全是有价值的数据，而且有噪声。你需要自行判断什么样的数据可以被拿来作为数据集。

注意，如果出现{{c1::}}这样的占位符，我们需要把它变成“什么”之类的字样使得问题合理化。答案就是{{c1::}}里的内容。

给定内容，提取其中有用的信息，进行提问。然后进行回答。组成问答对，请你帮我提取格式化成正确的json形式：

[{"query": 问题, "answer": 答案},
{"query": 问题, "answer": 答案},
...
]
注意，不要返回其他内容。所提的问题对医生来说要有意义。需要保证生成结果的json格式完整。

内容如下：

"""

def generate_dataset(text):
    t.init(visual_automation = True)
    t.url('https://www.chatgpt.com')

    def wait_until_present(selector, timeout=15):
        start_time = time.time()
        while time.time() - start_time < timeout:
            if t.present(selector):
                return True
            time.sleep(1)  # 等待1秒后再次检查
        t.close()
        raise TimeoutError(f"超过等待时间 {timeout} 秒，无法找到元素 {selector}")

    def wait_til_no_stop_or_continue_button():
        while True:
            # 如果存在“继续生成”按钮
            if t.present("继续生成"):
                t.click("继续生成")
                while not t.present("//button[contains(@data-testid, 'stop-button')]"):
                    t.wait(1)  # 等待直到“停止”按钮出现
                t.wait(2)  # 确保“停止”按钮完全加载
            else:
                # 等待直到“停止”按钮消失
                while t.present("//button[contains(@data-testid, 'stop-button')]"):
                    t.wait(1)  # 每秒检查一次
                t.wait(2)  # 确保“停止”按钮完全消失

            # 检查是否还有“继续生成”按钮
            if not t.present("继续生成"):
                break  # 没有“继续生成”按钮，退出循环
        return


    try:
        clip.copy(text)
        wait_until_present("//textarea[@id='prompt-textarea']")
        t.keyboard('[esc]')
        res = t.click("//textarea[@id='prompt-textarea']")
        print(f"点击状态: {res}")
        res = t.keyboard(f"{MODIFIER}v")
        print(f"粘贴状态: {res}")
        wait_until_present("//button[@data-testid='send-button']")
        res = t.click("//button[@data-testid='send-button']")
        print(f"点击发送状态：{res}")
  
        wait_til_no_stop_or_continue_button() 
        
        if t.present("复制代码"):
            copy_status = t.click("复制代码")
            print(f"复制状态: {copy_status}")
        # t.close()
        else:
            print(f"找不到： 复制代码 按钮")
    except Exception as e:
        print(f"捕捉到错误：{e}")
        t.close()
        return clip.paste()

    t.close()
    result_str = clip.paste()
    return result_str

# %%
txt_file = '麻醉试题/病理学问答题.txt'
# limit of message per hour
filebase = os.path.basename(txt_file).split('.')[-2]
sections = split_txt(txt_file)
for i in range(len(sections)):

    filename = f"gptqa/{filebase}_section{i}.json"
    if not os.path.exists(filename):
        ret = generate_dataset(prefix_prompt + sections[i])
        if ret == prefix_prompt + sections[i]:
            print(f"section {i} failed!")
        else:
            write_json(filename=filename, content=ret)
            print(f"i = {i}, successfully write {filename}.")
# Out:
# 点击状态: True
# 粘贴状态: True
# 点击发送状态：True
# 复制状态: True
# i = 0, successfully write 病理学问答题_section0.json.
# 点击状态: True
# 粘贴状态: True
# 点击发送状态：True
# 复制状态: True
# i = 1, successfully write 病理学问答题_section1.json.
# 点击状态: True
# 粘贴状态: True
# 点击发送状态：True
# 复制状态: True
# i = 2, successfully write 病理学问答题_section2.json.

# %%
import os 
txt_file = '麻醉试题/大三上学期__麻醉学.txt'
os.path.basename(txt_file).split('.')[-2]
# Out:
# '大三上学期__麻醉学'
